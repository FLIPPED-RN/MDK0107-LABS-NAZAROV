# %%
from random import randint

import lab3.mypackage.m1 as m1
from lab3.mypackage import m2

# %%
randomNumbers=[randint(-100,100) for i in range(200)]
print(randomNumbers)
# Out:
# [39, -30, 35, 72, 42, -19, -35, -50, 28, 45, 92, -5, -1, -57, 88, -12, 62, -29, 4, -98, -28, -28, 32, 82, -27, -43, 42, 15, 25, -35, 85, -92, 59, 25, -32, 8, -81, -50, -65, -68, 53, -35, 13, -19, -28, 80, -77, -62, 16, 54, -95, -33, -81, -82, 82, -18, 57, 22, -38, -53, 20, 12, -72, 53, 36, 24, -42, -61, -1, -53, -30, 25, -93, 9, 26, -28, -77, -95, -42, 24, 14, -99, 42, 65, -76, -48, 7, 57, 65, -54, 29, 47, -84, 99, -65, -71, 33, 17, -64, -97, -55, -81, 41, -37, -97, -84, 37, 4, -60, 17, 31, 17, 98, -62, 3, -84, 37, 63, -14, 93, 58, -16, -13, 60, -95, -72, -23, -18, -84, 96, -35, -36, 51, 98, -83, 12, 57, 51, 26, -71, -89, -34, -80, 57, -2, -93, -88, -16, -25, -85, -41, -6, -81, 30, 55, 27, -51, -45, 61, 31, -11, 18, -45, 70, 64, -94, 78, 13, -72, -97, -100, 86, 26, 32, -62, -59, 70, 37, -33, 56, -59, -9, -46, -68, 38, -55, -9, 95, 21, -56, -5, -52, -6, 74, 58, 77, -94, -70, 15, 21]

# %%
m1.run(randomNumbers)
# Out:
# успешно записано :)

# %%
m1.count_pars_words()
# Out:
# количество пар противоположных чисел: 44

# %%
N=100
filename="wassap2.txt"

m2.write_numbers(filename,N)
result=m2.min_max_sum(filename)

print("сумма минимального и максимального элементов:", result)
# Out:
# сумма минимального и максимального элементов: 6.757297112006867
