# %% [markdown]
# # Лабараторная ООП Назаров Руслан

# %% [markdown]
# 11.1 Вариант 4 |
# Поле 1 - Калорийность 100г продукта |
# Поле 2 - Вес продукта в граммах |
# Функция обработки полей - Вычислить общую калорийность продукта

# %%
class Product:
    product_name = ""
    calorie = 0
    weight = 0

class Vegetable:
    name = ""
    gram = 0
    calorie_vegetable = 0

cucumber = Vegetable()
cucumber.name = "огурец"
cucumber.gram = 100
cucumber.calorie_vegetable = 14

pomidor = Vegetable()
pomidor.name = "помидор"
pomidor.gram = 100
pomidor.calorie_vegetable = 23

product = Product()
product.product_name = "салат"
product.calorie = pomidor.calorie_vegetable + cucumber.calorie_vegetable
product.weight = cucumber.gram + pomidor.gram

print(calorie_content)
# Out:
# 0.25

# %% [markdown]
# 11.2 Вариант 4 | Класс родитель и его поля - Дата (три числа): часы, минуты, секунды | Функция-метод 1 обработки данных - Вычислить количество секунд в указанном времени
